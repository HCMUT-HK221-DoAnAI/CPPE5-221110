# %%
from app.yolov3 import Create_Yolov3
from app.configs import *
yolo = Create_Yolov3(input_size=YOLO_INPUT_SIZE, training=True, CLASSES=TRAIN_CLASSES)

# %%
yolo.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 640, 640, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 640, 640, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 640, 640, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  leaky_re_lu (LeakyReLU)        (None, 640, 640, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  zero_padding2d (ZeroPadding2D)  (None, 641, 641, 32  0          ['leaky_re_lu[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 320, 320, 64  18432       ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 320, 320, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 320, 320, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 320, 320, 32  2048        ['leaky_re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 320, 320, 32  128        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 320, 320, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 320, 320, 64  18432       ['leaky_re_lu_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 320, 320, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 320, 320, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  tf.__operators__.add (TFOpLamb  (None, 320, 320, 64  0          ['leaky_re_lu_1[0][0]',
#  da)                            )                                 'leaky_re_lu_3[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 321, 321, 64  0          ['tf.__operators__.add[0][0]']
#  D)                             )
#
#  conv2d_4 (Conv2D)              (None, 160, 160, 12  73728       ['zero_padding2d_1[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 160, 160, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 160, 160, 12  0           ['batch_normalization_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 160, 160, 64  8192        ['leaky_re_lu_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 160, 160, 64  256        ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 160, 160, 64  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 160, 160, 12  73728       ['leaky_re_lu_5[0][0]']
#                                 8)
#
#  batch_normalization_6 (BatchNo  (None, 160, 160, 12  512        ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 160, 160, 12  0           ['batch_normalization_6[0][0]']
#                                 8)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 160, 160, 12  0          ['leaky_re_lu_4[0][0]',
#  mbda)                          8)                                'leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 160, 160, 64  8192        ['tf.__operators__.add_1[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 160, 160, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 160, 160, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 160, 160, 12  73728       ['leaky_re_lu_7[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 160, 160, 12  512        ['conv2d_8[0][0]']
#  rmalization)                   8)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 160, 160, 12  0           ['batch_normalization_8[0][0]']
#                                 8)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 160, 160, 12  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                          8)                                'leaky_re_lu_8[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 161, 161, 12  0          ['tf.__operators__.add_2[0][0]']
#  D)                             8)
#
#  conv2d_9 (Conv2D)              (None, 80, 80, 256)  294912      ['zero_padding2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 80, 80, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 80, 80, 256)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 80, 80, 128)  32768       ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 80, 80, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_11[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 80, 80, 256)  0          ['leaky_re_lu_9[0][0]',
#  mbda)                                                            'leaky_re_lu_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 80, 80, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_13[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 80, 80, 256)  0          ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'leaky_re_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_4[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 80, 80, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_15[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 80, 80, 256)  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'leaky_re_lu_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_5[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 80, 80, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_17[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 80, 80, 256)  0          ['tf.__operators__.add_5[0][0]',
#  mbda)                                                            'leaky_re_lu_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_6[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 80, 80, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_19[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 80, 80, 256)  0          ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'leaky_re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_7[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 80, 80, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_21[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 80, 80, 256)  0          ['tf.__operators__.add_7[0][0]',
#  mbda)                                                            'leaky_re_lu_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_8[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 80, 80, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_23[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 80, 80, 256)  0          ['tf.__operators__.add_8[0][0]',
#  mbda)                                                            'leaky_re_lu_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 80, 80, 128)  32768       ['tf.__operators__.add_9[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 80, 80, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 80, 80, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 80, 80, 256)  294912      ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 80, 80, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 80, 80, 256)  0           ['batch_normalization_25[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 80, 80, 256)  0          ['tf.__operators__.add_9[0][0]',
#  ambda)                                                           'leaky_re_lu_25[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 81, 81, 256)  0          ['tf.__operators__.add_10[0][0]']
#  D)
#
#  conv2d_26 (Conv2D)             (None, 40, 40, 512)  1179648     ['zero_padding2d_3[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_26[0][0]']
#  ormalization)
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 40, 40, 256)  131072      ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_28[0][0]']
#  ormalization)
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_28[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 40, 40, 512)  0          ['leaky_re_lu_26[0][0]',
#  ambda)                                                           'leaky_re_lu_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_11[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_30[0][0]']
#  ormalization)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_30[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_11[0][0]',
#  ambda)                                                           'leaky_re_lu_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_12[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_32[0][0]']
#  ormalization)
#
#  leaky_re_lu_32 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_32[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_12[0][0]',
#  ambda)                                                           'leaky_re_lu_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_13[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  leaky_re_lu_33 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_34[0][0]']
#  ormalization)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_34[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_13[0][0]',
#  ambda)                                                           'leaky_re_lu_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_14[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  leaky_re_lu_35 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_36[0][0]']
#  ormalization)
#
#  leaky_re_lu_36 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_36[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_14[0][0]',
#  ambda)                                                           'leaky_re_lu_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_15[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_38[0][0]']
#  ormalization)
#
#  leaky_re_lu_38 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_38[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_15[0][0]',
#  ambda)                                                           'leaky_re_lu_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_16[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_40[0][0]']
#  ormalization)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_40[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_16[0][0]',
#  ambda)                                                           'leaky_re_lu_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 40, 40, 256)  131072      ['tf.__operators__.add_17[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 40, 40, 256)  1024       ['conv2d_41[0][0]']
#  ormalization)
#
#  leaky_re_lu_41 (LeakyReLU)     (None, 40, 40, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 40, 40, 512)  1179648     ['leaky_re_lu_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 40, 40, 512)  2048       ['conv2d_42[0][0]']
#  ormalization)
#
#  leaky_re_lu_42 (LeakyReLU)     (None, 40, 40, 512)  0           ['batch_normalization_42[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 40, 40, 512)  0          ['tf.__operators__.add_17[0][0]',
#  ambda)                                                           'leaky_re_lu_42[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, 41, 41, 512)  0          ['tf.__operators__.add_18[0][0]']
#  D)
#
#  conv2d_43 (Conv2D)             (None, 20, 20, 1024  4718592     ['zero_padding2d_4[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 20, 20, 1024  4096       ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_43 (LeakyReLU)     (None, 20, 20, 1024  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 20, 20, 512)  524288      ['leaky_re_lu_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 20, 20, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  leaky_re_lu_44 (LeakyReLU)     (None, 20, 20, 512)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 20, 20, 1024  4718592     ['leaky_re_lu_44[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 20, 20, 1024  4096       ['conv2d_45[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_45 (LeakyReLU)     (None, 20, 20, 1024  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  tf.__operators__.add_19 (TFOpL  (None, 20, 20, 1024  0          ['leaky_re_lu_43[0][0]',
#  ambda)                         )                                 'leaky_re_lu_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 20, 20, 512)  524288      ['tf.__operators__.add_19[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 20, 20, 512)  2048       ['conv2d_46[0][0]']
#  ormalization)
#
#  leaky_re_lu_46 (LeakyReLU)     (None, 20, 20, 512)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 20, 20, 1024  4718592     ['leaky_re_lu_46[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 20, 20, 1024  4096       ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_47 (LeakyReLU)     (None, 20, 20, 1024  0           ['batch_normalization_47[0][0]']
#                                 )
#
#  tf.__operators__.add_20 (TFOpL  (None, 20, 20, 1024  0          ['tf.__operators__.add_19[0][0]',
#  ambda)                         )                                 'leaky_re_lu_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 20, 20, 512)  524288      ['tf.__operators__.add_20[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 20, 20, 512)  2048       ['conv2d_48[0][0]']
#  ormalization)
#
#  leaky_re_lu_48 (LeakyReLU)     (None, 20, 20, 512)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 20, 20, 1024  4718592     ['leaky_re_lu_48[0][0]']
#                                 )
#
#  batch_normalization_49 (BatchN  (None, 20, 20, 1024  4096       ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_49 (LeakyReLU)     (None, 20, 20, 1024  0           ['batch_normalization_49[0][0]']
#                                 )
#
#  tf.__operators__.add_21 (TFOpL  (None, 20, 20, 1024  0          ['tf.__operators__.add_20[0][0]',
#  ambda)                         )                                 'leaky_re_lu_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 20, 20, 512)  524288      ['tf.__operators__.add_21[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 20, 20, 512)  2048       ['conv2d_50[0][0]']
#  ormalization)
#
#  leaky_re_lu_50 (LeakyReLU)     (None, 20, 20, 512)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 20, 20, 1024  4718592     ['leaky_re_lu_50[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 20, 20, 1024  4096       ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_51 (LeakyReLU)     (None, 20, 20, 1024  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  tf.__operators__.add_22 (TFOpL  (None, 20, 20, 1024  0          ['tf.__operators__.add_21[0][0]',
#  ambda)                         )                                 'leaky_re_lu_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 20, 20, 512)  524288      ['tf.__operators__.add_22[0][0]']
#
# ...
#                                                                  0]']
#
#  tf.__operators__.getitem_26 (S  (1, 20, 20, 1, 2)   0           ['tf.concat_8[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  (None, 80, 80, 3, 2  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.tile_2 (TFOpLambda)         (None, 80, 80, 3, 2  0           ['tf.__operators__.getitem_8[0][0
#                                 )                                ]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.__operators__.getitem_3 (Sl  (None, 80, 80, 3, 2  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.__operators__.getitem_11 (S  (None, 40, 40, 3, 2  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.tile_5 (TFOpLambda)         (None, 40, 40, 3, 2  0           ['tf.__operators__.getitem_17[0][
#                                 )                                0]',
#                                                                   'tf.__operators__.getitem_9[0][0
#                                                                  ]']
#
#  tf.__operators__.getitem_12 (S  (None, 40, 40, 3, 2  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.__operators__.getitem_20 (S  (None, 20, 20, 3, 2  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.tile_8 (TFOpLambda)         (None, 20, 20, 3, 2  0           ['tf.__operators__.getitem_26[0][
#                                 )                                0]',
#                                                                   'tf.__operators__.getitem_18[0][
#                                                                  0]']
#
#  tf.__operators__.getitem_21 (S  (None, 20, 20, 3, 2  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.math.sigmoid (TFOpLambda)   (None, 80, 80, 3, 2  0           ['tf.__operators__.getitem_2[0][0
#                                 )                                ]']
#
#  tf.cast (TFOpLambda)           (None, 80, 80, 3, 2  0           ['tf.tile_2[0][0]']
#                                 )
#
#  tf.math.exp (TFOpLambda)       (None, 80, 80, 3, 2  0           ['tf.__operators__.getitem_3[0][0
#                                 )                                ]']
#
#  tf.math.sigmoid_3 (TFOpLambda)  (None, 40, 40, 3, 2  0          ['tf.__operators__.getitem_11[0][
#                                 )                                0]']
#
#  tf.cast_1 (TFOpLambda)         (None, 40, 40, 3, 2  0           ['tf.tile_5[0][0]']
#                                 )
#
#  tf.math.exp_1 (TFOpLambda)     (None, 40, 40, 3, 2  0           ['tf.__operators__.getitem_12[0][
#                                 )                                0]']
#
#  tf.math.sigmoid_6 (TFOpLambda)  (None, 20, 20, 3, 2  0          ['tf.__operators__.getitem_20[0][
#                                 )                                0]']
#
#  tf.cast_2 (TFOpLambda)         (None, 20, 20, 3, 2  0           ['tf.tile_8[0][0]']
#                                 )
#
#  tf.math.exp_2 (TFOpLambda)     (None, 20, 20, 3, 2  0           ['tf.__operators__.getitem_21[0][
#                                 )                                0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 80, 80, 3, 2  0          ['tf.math.sigmoid[0][0]',
#  ambda)                         )                                 'tf.cast[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 80, 80, 3, 2  0          ['tf.math.exp[0][0]']
#  )                              )
#
#  tf.__operators__.add_24 (TFOpL  (None, 40, 40, 3, 2  0          ['tf.math.sigmoid_3[0][0]',
#  ambda)                         )                                 'tf.cast_1[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 40, 40, 3, 2  0          ['tf.math.exp_1[0][0]']
#  )                              )
#
#  tf.__operators__.add_25 (TFOpL  (None, 20, 20, 3, 2  0          ['tf.math.sigmoid_6[0][0]',
#  ambda)                         )                                 'tf.cast_2[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 20, 20, 3, 2  0          ['tf.math.exp_2[0][0]']
#  )                              )
#
#  tf.math.multiply (TFOpLambda)  (None, 80, 80, 3, 2  0           ['tf.__operators__.add_23[0][0]']
#                                 )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 80, 80, 3, 2  0          ['tf.math.multiply_1[0][0]']
#  )                              )
#
#  tf.__operators__.getitem_4 (Sl  (None, 80, 80, 3, 1  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.__operators__.getitem_5 (Sl  (None, 80, 80, 3, 5  0          ['tf.reshape[0][0]']
#  icingOpLambda)                 )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 40, 40, 3, 2  0          ['tf.__operators__.add_24[0][0]']
#  )                              )
#
#  tf.math.multiply_5 (TFOpLambda  (None, 40, 40, 3, 2  0          ['tf.math.multiply_4[0][0]']
#  )                              )
#
#  tf.__operators__.getitem_13 (S  (None, 40, 40, 3, 1  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.__operators__.getitem_14 (S  (None, 40, 40, 3, 5  0          ['tf.reshape_1[0][0]']
#  licingOpLambda)                )
#
#  tf.math.multiply_6 (TFOpLambda  (None, 20, 20, 3, 2  0          ['tf.__operators__.add_25[0][0]']
#  )                              )
#
#  tf.math.multiply_8 (TFOpLambda  (None, 20, 20, 3, 2  0          ['tf.math.multiply_7[0][0]']
#  )                              )
#
#  tf.__operators__.getitem_22 (S  (None, 20, 20, 3, 1  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.__operators__.getitem_23 (S  (None, 20, 20, 3, 5  0          ['tf.reshape_2[0][0]']
#  licingOpLambda)                )
#
#  tf.concat_3 (TFOpLambda)       (None, 80, 80, 3, 4  0           ['tf.math.multiply[0][0]',
#                                 )                                 'tf.math.multiply_2[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, 80, 80, 3, 1  0          ['tf.__operators__.getitem_4[0][0
#                                 )                                ]']
#
#  tf.math.sigmoid_2 (TFOpLambda)  (None, 80, 80, 3, 5  0          ['tf.__operators__.getitem_5[0][0
#                                 )                                ]']
#
#  tf.concat_6 (TFOpLambda)       (None, 40, 40, 3, 4  0           ['tf.math.multiply_3[0][0]',
#                                 )                                 'tf.math.multiply_5[0][0]']
#
#  tf.math.sigmoid_4 (TFOpLambda)  (None, 40, 40, 3, 1  0          ['tf.__operators__.getitem_13[0][
#                                 )                                0]']
#
#  tf.math.sigmoid_5 (TFOpLambda)  (None, 40, 40, 3, 5  0          ['tf.__operators__.getitem_14[0][
#                                 )                                0]']
#
#  tf.concat_9 (TFOpLambda)       (None, 20, 20, 3, 4  0           ['tf.math.multiply_6[0][0]',
#                                 )                                 'tf.math.multiply_8[0][0]']
#
#  tf.math.sigmoid_7 (TFOpLambda)  (None, 20, 20, 3, 1  0          ['tf.__operators__.getitem_22[0][
#                                 )                                0]']
#
#  tf.math.sigmoid_8 (TFOpLambda)  (None, 20, 20, 3, 5  0          ['tf.__operators__.getitem_23[0][
#                                 )                                0]']
#
#  tf.concat_4 (TFOpLambda)       (None, 80, 80, 3, 1  0           ['tf.concat_3[0][0]',
#                                 0)                                'tf.math.sigmoid_1[0][0]',
#                                                                   'tf.math.sigmoid_2[0][0]']
#
#  tf.concat_7 (TFOpLambda)       (None, 40, 40, 3, 1  0           ['tf.concat_6[0][0]',
#                                 0)                                'tf.math.sigmoid_4[0][0]',
#                                                                   'tf.math.sigmoid_5[0][0]']
#
#  tf.concat_10 (TFOpLambda)      (None, 20, 20, 3, 1  0           ['tf.concat_9[0][0]',
#                                 0)                                'tf.math.sigmoid_7[0][0]',
#                                                                   'tf.math.sigmoid_8[0][0]']
#
# ==================================================================================================
# Total params: 61,597,882
# Trainable params: 61,545,274
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
